# %% [markdown]
# ### Exceptions Handling

# %%
try:
    a=b
except:
    print('Hey the variable is not been assigned')
# Out:
# Hey the variable is not been assigned

# %%
a=b
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 a=b
#
# NameError: name 'b' is not defined

# %%
try:
    a=b
except NameError as ex:
    print(ex)
# Out:
# name 'b' is not defined

# %%
result = 1/0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 result = 1/0
#
# ZeroDivisionError: division by zero

# %%
try:
    re = 1/0
except ZeroDivisionError as ex:
    print(ex)
    print('Hey use some number instead denominator 0')
# Out:
# division by zero
# Hey use some number instead denominator 0

# %%
try:
    re = 1/2
    c=d
except ZeroDivisionError as ex:
    print(ex)
    print('Hey use some number instead denominator 0')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 4
#       1 try:
#       2     re = 1/2
#       3     c=d
# ----> 4 except ZeroDivisionError as ex:
#       5     print(ex)
#       6     print('Hey use some number instead denominator 0')
#
# NameError: name 'd' is not defined

# %%
try:
    re = 1/2
    c=d
except ZeroDivisionError as ex:
    print(ex)
    print('Hey use some number instead denominator 0')

except Exception as ex1:
    print(ex1)
# Out:
# name 'd' is not defined

# %%
try:
    num = int(input('Enter a number:'))
    result = 10/num

except ZeroDivisionError as ex:
    print('Hey do not use 0 as denominator')

except ValueError as ex:
    print('Hey do not use string')

except Exception as ex1:
    print(ex1)

else:
    print(f'the result is: {result}')

finally:
    print('Execution Completed')
# Out:
# Hey do not use 0 as denominator
# Execution Completed
