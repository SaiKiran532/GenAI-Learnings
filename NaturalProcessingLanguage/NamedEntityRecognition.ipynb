# %% [markdown]
# What is Named Entity Recognition (NER)?
#
# Named Entity Recognition (NER) is the process of identifying and classifying important entities in text into predefined categories such as:
#
# Person
# Organization
# Location
# Date
# Time
# Money
# Percentage
# Product
# Event
#
# In simple terms, NER answers the question:
#
# "Which words in this sentence refer to real-world entities?"
#
# Example 1
#
# Sentence:
#
# "Elon Musk is the CEO of Tesla and lives in Texas."
#
# | Word      | Entity Type  |
# | --------- | ------------ |
# | Elon Musk | PERSON       |
# | Tesla     | ORGANIZATION |
# | Texas     | LOCATION     |
#
# Example 2
#
# Sentence:
#
# "Apple launched the iPhone 16 in California on September 9, 2025."
#
# | Entity            | Type         |
# | ----------------- | ------------ |
# | Apple             | ORGANIZATION |
# | iPhone 16         | PRODUCT      |
# | California        | LOCATION     |
# | September 9, 2025 | DATE         |

# %%
import nltk
nltk.download('maxent_ne_chunker_tab')
nltk.download('words')
# Out:
# [nltk_data] Downloading package maxent_ne_chunker_tab to
# [nltk_data]     C:\Users\Dell\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping chunkers\maxent_ne_chunker_tab.zip.
# [nltk_data] Downloading package words to
# [nltk_data]     C:\Users\Dell\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\words.zip.
# True

# %%
import nltk
from nltk.tokenize import word_tokenize

sentence = "Elon Musk is the CEO of Tesla and lives in Texas."

# Step 1: Tokenize
tokens = word_tokenize(sentence)

# Step 2: POS Tagging
pos_tags = nltk.pos_tag(tokens)

# Step 3: Named Entity Recognition
ner_tree = nltk.ne_chunk(pos_tags).draw()
# Out:
# None

# %%
for subtree in ner_tree:
    if hasattr(subtree, "label"):
        entity = " ".join(token for token, pos in subtree.leaves())
        print(entity, "->", subtree.label())
# Out:
# Elon -> PERSON
# Musk -> ORGANIZATION
# CEO of Tesla -> ORGANIZATION
# Texas -> GPE
